# %%
for i in range(int(input())):
    n = int(input())
    li = [int(i) for i in input().split()]
    li.sort(reverse = True)
    if n == 1:
        print(li[0])
        continue
    elif n == 2:
        print(max(li[0], li[1]))
        continue
    count = li[1]
    remainder = li[0] - li[1]
    for i in range(2, n):
        count += min(remainder, li[i])
        remainder = abs(remainder - li[i])
    print(count)

# %%
for i in range(int(input())):
    n = int(input())
    li = [int(i) for i in input().split()]
    li.sort(reverse = True)
    if n == 1:
        print(li[0])
        continue
    elif n == 2:
        print(max(li[0], li[1]))
        continue
    count = li[1]
    remainder = li[0] - li[1]
    i = 2
    while i <= n-1:
        if remainder == 0:
            if i+1 <= n-1:
                count += li[i+1]
                remainder = li[i] - li[i+1]
                i += 1
            else:
                count += li[i]
                remainder = 0
            i += 1
        else:
            if li[i] != 0:
                count += min(remainder, li[i])
            else:
                count += remainder
            remainder = abs(remainder - li[i])
            i += 1
    count += remainder
    print(count)
# Out:
# 1

# %%
n = 1
if n != 1:
    for i in range(2, n):
        if n % i == 0:
            print("not prime")
            break
    else:
        print("prime")
else:
    print("not prime")
# Out:
# not prime

# %%
for _ in range(int(input())):
    n = int(input())
    b = [int(i) for i in input().split()]
    primes = []
    for j in range(1, n*n, 1):
        if len(primes) < n:
            if j != 1:
                for i in range(2, j):
                    if j % i == 0:
                        break
                else:
                    primes.append(j)
        else:
            break
    if n == 1:
        primes.append(2)
    mydict = {}
    for i in range(n):
        if b[i] == i+1:
            pass
        else:
            if b[i]-1 not in mydict:
                primes[b[i] - 1] = primes[i]
                mydict[b[i]-1] = 1
            else:
                primes[b[i] - 1] *= primes[i]
    print(*primes)
# Out:
# 1
# 8
# 6 2 3 4 5 8 7 8
# 2 3 5 7 11 2 17 2

# %%
def generate_n_primes(N):
    primes  = []
    chkthis = 2
    while len(primes) < N:
        ptest    = [chkthis for i in primes if chkthis%i == 0]
        primes  += [] if ptest else [chkthis]
        chkthis += 1
    return primes
for _ in range(int(input())):
    n = int(input())
    b = [int(i) for i in input().split()]
    primes = generate_n_primes(n)
    mydict = {}
    for i in range(n):
        if b[i] == i+1:
            pass
        else:
            if b[i]-1 not in mydict:
                primes[b[i] - 1] = primes[i]
                mydict[b[i]-1] = 1

                else:
                primes[b[i] - 1] *= primes[i]
    print(*primes)

# %%
try:
    from math import *
    maxn = 1299720
    def sieveoferat():
        primes = [True] * maxn
        primes[0], primes[1] = False, False
        for i in range(2, int(sqrt(maxn)) + 1):
            if primes[i] == True:
                for j in range(i**2, maxn, i):
                    primes[j] = False
        newprimes = []
        for i in range(maxn):
            if primes[i] == True:
                newprimes.append(i)
        print(len(newprimes))
        return newprimes
    primes = sieveoferat()
    t = int(input())
    for i in range(t):
        n = int(input())
        b = [int(i) for i in input().split()]
        c = primes[:n:1]
        for i in range(n):
            if b[i] != i + 1:
                c[i] = c[b[i] - 1]
        print(*c)
except:
    pass
# Out:
# 100000

# %%
for i in range(int(input())):
    n, k = map(int, input().split())
    s = input()
    stack = []
    i, res, count1, count2 = 0, 0, 0, 0
    while i < n:
        if not stack:
            stack.append(s[i])
            i += 1
        else:       
            if stack[-1] == 'M' or stack[-1] == '_':
                if s[i] == 'M' or s[i] == '_':
                    stack.append(s[i])
                    i += 1
                elif s[i] == 'I':
                    while stack and stack[-1] == '_':
                        stack.pop()
                        count1 += 1
                    diff = count1 + 1
                    if k + 1 - diff > 0:
                        i += 1
                        res += 1
                        count1 = 0
                    else:
                        count1 += 1
                    if stack:
                        stack.pop()
            elif stack[-1] == 'I' or stack[-1] == '_':
                if s[i] == 'I' or s[i] == '_':
                    stack.append(s[i])
                    i += 1
                elif s[i] == 'M':
                    while stack and stack[-1] == '_':
                        stack.pop()
                        count2 += 1
                    diff = count2 + 1
                    if k + 1 - diff > 0:
                        i += 1
                        res += 1
                        count2 = 0
                    else:
                        count2 += 1
                    if stack:
                        stack.pop()
            else:
                stack = []
                count1 = 0
                count2 = 0
                i += 1
        print(stack)
        
    print(res)

# %%
s = 'M-M-I'.strip().split('')
print(str(s))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-075587eda5bc> in <module>
# ----> 1 s = 'M-M-I'.strip().split('')
#       2 print(str(s))
#
# ValueError: empty separator

# %%
def finds(i, j):
    count = 0
    if i < j:
        for p in range(i, j+1):
            if p == ':':
                count += 1
    elif i>j:
        for p in range(j, i+1):
            if p == ':':
                count += 1
    return count
for i in range(int(input())):
    n, k = map(int, input().split())
    s = input()
    i, j = 0, 0
    c = 0
    ans = 0
    while i <n and j <n:
        if s[i] == 'M':
            if s[j] == 'I':
                c = finds(i, j)
                if (k + 1 - abs(i - j) - c) > 0:
                    ans += 1
                    i += 1
                    j += 1
                    c = 0
                elif p < 0:
                    if i < j:
                        i -= 1
                        j += 1
                    else:
                        i += 1
                        j -= 1
            elif s[j] == 'X':
                i = j
                i += 1
                j += 1
                
            
            else:
                j += 1
        elif s[i] == 'X':
            j = i
            j += 1
            i += 1
            
        else:
            i += 1
print(ans)

# %%
tc=int(input())
while(tc>0):
    n,k=map(int,input().split())
    s=input()
    p=k+1 
    i=0
    j=0
    ans=0
    c=0
    if(len(s)==1): 
        ans=0
    else:
        while(i<n and j<n):
            if(s[i]=="M"):
                if(s[j]=="I"):
                    
                    if(i>j):
                        for t in range(j,i+1):
                            if(s[t]==':'):
                                c=c+1  
                    else:
                        for t in range(i,j+1):
                            if(s[t]==':'):
                                c=c+1 
                        
                    f=p-abs(i-j)-c
                    if(f>0):
                        c=0
                        ans=ans+1
                        i=i+1 
                        j=j+1 
                    else: 
                        c=0
                        if(i>j):
                            j=j+1 
                        else:
                            i=i+1 
                elif(s[j]=="X"):
                    i=j 
                    i=i+1 
                    j=j+1 
                    c=0
                else:
                    j=j+1 
            elif(s[i]=="X"):
                j=i
                c=0
                i=i+1 
                j=j+1 
            
            else:
                i=i+1
    
                
    print(ans)
    tc=tc-1

# %%
for _ in range(int(input())):
    n = int(input())
    a = [int(i) for i in input().split()]
    for j in range(int(input())):
        r = int(input())
        count = 0
        i = 0
        while i < r:
            c = a[i % n]
            print(c)
            if c % 2 == 0:
                if i != n-1 or r <= n:
                    count += c
                else:
                    count += c - 1
            else:
                if i != n - 1 and c != 1:
                    count += c - 1
                elif c != 1 and i != n -1:
                    count += c
                else:
                    count += 1
                    if i != n - 2:
                        i += 1
                    else:
                        i += 2
                        
            i += 1
        print(count)

# %%
for i in range(int(input())):
    x, y = map(int, input().split())
    if x < y:
        if x % 2 == 0 and y % 2 == 0:
            print(2)
        elif x % 2 != 0 and y % 2 != 0:
            print(2)
        else:
            print(1)
    else:
        if x % 2 == 0 and y % 2 == 0:
            print(1)
        elif x % 2 != 0 and y % 2 != 0:
            print(1)
        else:
            print(2)
# Out:
# 3
# 0 5
# 1
# 4 -5
# 2
# 0 10000001
# 1
