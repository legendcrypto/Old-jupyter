# %%
t = int(input())
for i in range(t):
    n, k, x, y = (int(i) for i in input().split())
    i = (x + k) % n
    visited = []
    visited.append(x)
    while i <= n-1:
        print(i)
        if i not in visited and i == y:
            print("YES")
            break
        elif i in visited:
            print("NO")
            break
        visited.append(i)
        i = (i + k) % (n-1)

# %%
t = int(input())
for i in range(t):
    n, k, x, y = (int(i) for i in input().split())
    i = x
    visited = []
    while i <= n-1:
        print(i)
        if i not in visited and i == y:
            print("YES")
            break
        elif i in visited:
            print("NO")
            break
        visited.append(i)
        i = (i + k) % (n-1)

# %%
for i in range(int(input())):
    n, k = (int(i) for i in input().split())
    li = [int(i) for i in input().split()]
    
    prev = 0
    for i, j in enumerate(li):
        net = j + prev
        if k > net:
            print(i+1)
            break
        elif net >= k:
            prev = net - k
    else:
        res = (prev // k) + i + 2
        print(res)

# %%
from math import log2, ceil, floor
def ispowerof2(n):
    if n == 0:
        return False
    return ceil(log2(n)) == floor(log2(n))
for i in range(int(input())):
    n = int(input())
    if n == 1:
        print(1)
    elif ispowerof2(n):
        print(-1)
    else:
        print(2, 3, 1, end = " ")
        i = 4
        while i <= n:
            if ispowerof2(i):
                print(i+1, i, end = " ")
                i += 1
            else:
                print(i, end = " ")
            i += 1
        print()

# %%
from math import log2, ceil, floor
def ispowerof2(n):
    if n == 0:
        return False
    return ceil(log2(n)) == floor(log2(n))
for i in range(int(input())):
    n = int(input())
    li = []
    if n == 1:
        print(1)
    elif n == 3:
        print(1, 3, 2)
    elif n == 5:
        print(2, 3, 1, 5, 4)
    elif ispowerof2(n):
        print(-1)
    else:
        print(2, 3, 1, 5, 4, end = " ")
        i = 6
        while i <= n:
            if ispowerof2(i):
                print(i+1, i, end = " ")
                i += 2
            else:
                print(i, end = " ")
                i += 1
        print()

# %%
li = [int(i) for i in input().split()]
li.sort()
print(li)
li = [int(i) for i in input().split()]
li.sort()
print(li)

# %%
def pos(x, li):
    for i in range(1, n+1):
        if li[i] == x:
            return i
for i in range(int(input())):
    n, x, p, k = (int(i) for i in input().split())
    lis = [int(i) for i in input().split()]
    lis.sort()
    if x not in lis:
        lis[k-1] = x
    li = [None] + lis
    posi = pos(x, li)
    if p > posi:
        if k > posi:
            print(p - posi)
        else:
            print(-1)
    elif p < posi:
        if k < posi:
            print(posi - p)
        else:
            print(-1)
    else:
        print(0)

# %%
li = [1, 2, 3, -1, 0]
li.sort()
print(li)

# %%
t = int(input())
for i in range(t):
    n = int(input())
    s = input()
    a = ''
    b = ''
    if n % 2 == 0:
        l = n//2 
    else:
        l = n//2 + 1
    for i in range(0, l, 1):
        a = a + s[i]
    for i in range(l, n, 1):
        b = b + s[i]
    for i in len(a):
        if a == b:
            print("YES")
        a = a[1::]
    else:
        print("NO")

# %%
b = "abcd" - "a"
print(b)

# %%
a = 'a'
d = "abcd".replace(a, '')
d.pop(0)
print(d)
print(len(d))

# %%
for i in range(int(input())):
    n = int(input())
    st = input()
    if st[-1] in st[0:n-1:1]:
        print("YES")
    else:
        print("NO")

# %%
s = "abcd"
print(s.find('b') + 1)
# Out:
# 2

# %%
# cook your dish here
class Node:
    def __init__(self,val,ass,left=None,right=None):
        self.val=val
        self.ass=ass
        self.left=left
        self.right=right
        
def min_value(node):
    current=node
    while current.left is not None:
        current=current.left
    return current
    
def insert(root,b,a):
    if root is None:
        root=Node(b,a)
        print(a)
    elif b<root.val:
        root.left=insert(root.left,b,2*a)
    else:
        root.right=insert(root.right,b,(2*a)+1)
    return root

def delete(root,b,v):
    if root==None:
        return root
    if b < root.val:
        root.left = delete(root.left, b, v)
    elif b > root.val:
        root.right = delete(root.right, b, v)
    else:
        if root.left == None and root.right == None:
            
    return root
    
root = None
for _ in range(int(input())):
    a,b = input().split()
    b = int(b)
    if a == 'i':
        root = insert(root,b,1)
    else:
        root = delete(root,b,True)
# Out:
#   File "<ipython-input-8-db1da0035040>", line 35
#     return root
#     ^
# IndentationError: expected an indented block

# %%
class Node:
    def __init__(self,val,ass,left=None,right=None):
        self.val=val
        self.ass=ass
        self.left=left
        self.right=right
def min_value(node):
    current=node
    while current.left is not None:
        current=current.left
    return current       
def insert(root, b, a):
    if root == None:
        root = Node(b, a)
        print(a)
        return root
    elif b < root.value:
        root.left = insert(root.left, b, 2*a)
    elif b > root.value:
        root.left = insert(root.left, b, (2*a) + 1)
    return root
        
def delete(root,b,v):
    if root==None:
        return root
    if b < root.val:
        root.left = delete(root.left, b, v)
    elif b > root.val:
        root.right = delete(root.right, b, v)
    else:
        if v:
            print(root.ass)
        if root.left == None:
            temp = root.right
            root = None
            return temp
        elif root.right == None:
            temp = root.left
            root = None
            return temp
        
        temp=min_value(root.right)
        root.val=temp.val
        root.right = delete(root.right, temp.val, False)
    return root
root = None
for _ in range(int(input())):
    a,b = input().split()
    b = int(b)
    if a == 'i':
        root = insert(root,b,1)
    else:
        root = delete(root,b,True)

# %%
t=int(input())
for j in range(t):
    n,l,r=map(int,input().split())
    num=r-l+1
    even=num//2
    odd=num-even
    if r % 2 == 0 and l % 2 == 0:
        even = num//2 + 1
        odd = num - even
    for i in range(n):
        print(even,odd)
        w,b=(map(int,input().split()))
        if w%2==0 and b%2==0:
            even=even+odd
            odd=0
        elif w%2==1 and b%2==1:
            temp=even
            even=odd
            odd=temp
        elif w%2==0 and b%2==1:
            odd=even+odd
            even=0
    print(even,odd)
# Out:
# 1
# 1 2 10
# 5 4
# 1 1
# 4 5

# %%
t=int(input())
for j in range(t):
    n,l,r=map(int,input().split())
    num=r-l+1
    even=num//2
    odd=num-even
    for i in range(n):
        print(even,odd)
        w,b=(map(int,input().split()))
        if w%2==0 and b%2==0:
            even=even+odd
            odd=0
        elif w%2==1 and b%2==1:
            temp=even
            even=odd
            odd=temp
        elif w%2==0 and b%2==1:
            odd=even+odd
            even=0
    print(even,odd)

# %%
for i in range(int(input())):
    mydict = {}
    for i in range(12):
        liom = input().split()
        goala = int(liom[1])
        goalb = int(liom[3])
        teama = liom[0]
        teamb = liom[4]
        if goala > goalb:
            if teamb not in mydict:
                mydict[teamb] = [0, goalb - goala]
            if teama not in mydict:
                mydict[teama] = [3, goala - goalb]
                continue
            if teama and teamb in mydict:
                mydict[teama][0] += 3
                mydict[teama][1] += goala - goalb
                mydict[teamb][1] += goalb - goala
        elif goala < goalb:
            if teamb not in mydict:
                mydict[teamb] = [3, goalb - goala]
            if teama not in mydict:
                mydict[teama] = [0, goala - goalb]
            elif teama and teamb in mydict:
                mydict[teamb][0] += 3
                mydict[teamb][1] += goalb - goala
                mydict[teamb][1] += goala - goalb
        else:
            if teama not in mydict:
                mydict[teama] = [1, 0]
            else:
                mydict[teama][0] += 1
            if teamb not in mydict:
                mydict[teamb] = [1, 0]
            else:
                mydict[teamb][0] += 1
            
        print(mydict)

# %%
for i in range(int(input())):
    mydict = {}
    for i in range(12):
        liom = input().split()
        goala = int(liom[1])
        goalb = int(liom[3])
        teama = liom[0]
        teamb = liom[4]
        if teama not in mydict:
            mydict[teama] = [0, 0]
        if teamb not in mydict:
            mydict[teamb] = [0, 0]
        mydict[teama][1] += goala - goalb
        mydict[teamb][1] += goalb - goala
        if goala > goalb:
            mydict[teama][0] += 3
        elif goala < goalb:
            mydict[teamb][0] += 3
        else:
            mydict[teama][0] += 1
            mydict[teamb][0] += 1
    def get_key(val): 
        for key, value in mydict.items(): 
            if val == value: 
                 return key 
    sh = []
    h = []
    stsh = ''
    sth = ''
    for i in mydict:
        if mydict[i] > h:
            sh = h
            stsh = get_key(sh)
            h = mydict[i]
            sth = i
            
        elif mydict[i] > sh:
            sh = mydict[i]
            stsh = i
    print(sth, stsh)
# Out:
# 1
# a 3 vs. 0 b
# a 0 vs. 0 c
# a 0 vs. 0 d
# b 0 vs. 0 a
# b 4 vs. 0 c
# b 0 vs. 0 d
# c 0 vs. 0 a
# c 0 vs. 0 b
# c 1 vs. 0 d
# d 3 vs. 0 a
# d 0 vs. 0 b
# d 0 vs. 0 c
# d b

# %%
li = [2, 1, 3, 5]
h = -1
sh = -1
for i in li:
    if i > h:
        sh = h
        h = i
    elif i > sh:
        sh = i
print(h, sh)
# Out:
# 5 3

# %%
for i in range(int(input())):
    n, a, k = map(int, input().split())
    angle = a * k
    print(angle, 1)

# %%
# cook your dish here
for _ in range(int(input())):
    n=int(input())
    A=[]
    B=[]
    for i in range(n):
        x=int(input())
        a=x&((1<<16)-1)
        b=x>>16
        A.append(a)
        B.append(b)
    print('Case %d:'%(_+1))
    print(*A)
    print(*B)

# %%
for i in range(int(input())):
    k = int(input())
    cb = [['X' for j in range(8)] for i in range(8)]
    print(cb)
    for i in range(8):
        for j in range(8):
            if i == 0 and j == 0:
                cb[i][j] = 'O'
                continue
            elif k > 1:
                cb[i][j] = '.'
                k -= 1
        
        
    for i in cb:
        print(*i)

# %%
for i in range(int(input())):
    k = int(input())
    cb = [['X' for j in range(8)] for i in range(8)]

    for i in range(8):
        for j in range(8):
            if i == 0 and j == 0:
                cb[i][j] = 'O'
                continue
            elif k > 1:
                cb[i][j] = '.'
                k -= 1
            else:
                cb[i][j] = 'X'
        
    for i in cb:
        print(*i)

# %%
for i in range(int(input())):
    li = input().split(':')
    y = int(li[0])
    m = int(li[1])
    d = int(li[2])
    if m == 1 or m == 3 or m == 5 or m == 7 or m == 8 or m == 10 or m == 12:
        count = (31 - d)//2 + 1
    elif m == 4 or m == 6 or m == 9 or m == 11:
        count = (30 + 31 - d)//2 + 1
    else:
        if (y % 4 == 0 and y % 100 != 0) or y % 400 == 0:
            count = (29 - d)//2 + 1
        else:
            count = (28 + 31 - d)//2 + 1
    print(count)
# Out:
# 1
# 2020:1:2
# 15

# %%
# cook your dish here
t = int(input())

for _ in range(t):
    s = input()
    a = s.split(":")
    y = int(a[0])
    m = int(a[1])
    d = int(a[2])

    if m == 1 or m == 3 or m == 5 or m == 7 or m == 8 or m == 10 or m == 12:
        count = (31 - d) // 2 + 1
    elif m == 4 or m == 6 or m == 9 or m == 11:
        count = (30 + 31 - d) // 2 + 1
    else:
        if y % 4 == 0 and y % 100 != 0 or y % 400 == 0:
            count = (29 - d) // 2 + 1
        else:
            count = (28 + 31 - d) // 2 + 1
    print(count)

# %%
for i in range(int(input())):
    s, sg, fg, d, t = map(int, input().split())
    netv = s + (d * 180)/t
    if abs(netv - sg) < abs(netv - fg):
        print("SEBI")
    elif abs(netv - sg) > abs(netv - fg):
        print("FATHER")
    else:
        print("DRAW")

# %%
for i in range(int(input())):
    n, h, y1, y2, L = map(int, input().split())
    count = 0
    li = []
    for i in range(n):
        t, x = map(int, input().split())
        li.append([t, x])
    for i in range(n):
        t, x = 0, 0
        t = li[i][0]
        x = li[i][1]
        if t == 1:
            if h - y1 <= x:
                count += 1
            else:
                if L > 1:
                    L -= 1
                    count += 1
                elif L == 1:
                    L = 0
                    break
        else:
            if y2 >= x:
                count += 1
            else:
                if L > 1:
                    L -= 1
                    count += 1
                elif L == 1:
                    L = 0
                    break
    print(count)
# Out:
# 1
# 1 2 1 1 0
# 2 4
# 0

# %%
t=int(input())
for i in range(t):
    n,h,y1,y2,l=map(int,input().split())
    list1=[]
    for i in range(n):
        T,X=map(int,input().split())
        list1.append([T,X])
    c=0
    for i in range(n):
        t=0
        x=0
        t=list1[i][0]
        x=list1[i][1]
        d1=0
        d1=h-y1
        if(t==1):
            if(d1<=x):
                c+=1
            elif(d1>x):
                if(l>0):
                    l-=1
                    c+=1
                else:
                    break
        elif(t==2):
            if(y2>=x):
                c+=1
            elif(y2<x):
                if(l>0):
                    l-=1
                    c+=1
                else:
                    break
    if l == 0:
        print(c -1)
    else:
        print(c)

# %%
for i in range(int(input())):
    n, h, y1, y2, L = map(int, input().split())
    count = 0
    li = []
    for i in range(n):
        t, x = map(int, input().split())
        li.append([t, x])
    for i in range(n):
        t, x = 0, 0
        t = li[i][0]
        x = li[i][1]
        if t == 1 and L > 0:
            if h - y1 <= x:
                count += 1
            else:
                if L > 0:
                    L -= 1
                    count += 1
                else:
                    break
        elif t == 2 and L > 0:
            if y2 >= x:
                count += 1
            else:
                if L > 0:
                    L -= 1
                    count += 1
                else:
                    break
    else:
        print(count)
        continue
        
        
    if L == 0:
        print(count - 1)
    else:
        print(count)

# %%
for i in range(int(input())):
    l, k = map(int, input().split())
    n = l - k + 1 
    ans = n*(n+1)//2
    print("Case ", (i+1) ,':' , ans)

# %%
mydict = {'monday' : 1, 'tuesday' : 2, "wednesday" : 3, "thursday" : 4, "friday" : 5, "saturday" : 6, "sunday" : 7}
for i in range(int(input())):
    d1, d2, r1, r2 = input().split()
    d1 = mydict[d1]
    d2 = mydict[d2]
    r1 = int(r1)
    r2 = int(r2)
    if d2 < d1:
        dr = d2 - d1 + 8
    else:
        dr = d2 - d1 + 1
    if dr <= r2 - r1 + 1 and (dr in range(r1, r2+1) or :
            print("many")
        else:
            print(dr)
    else:
        print("impossible")
# Out:
# 1
# saturday thursday 8 20
# impossible

# %%
# cook your dish here
t = (int)(input())
d={"saturday":0,"sunday":1,"monday":2,"tuesday":3,"wednesday":4,"thursday":5,"friday":6}
while t > 0:
    li=list(input().strip().split(' '))
    s=li[0]
    e=li[1]
    l=(int)(li[2])
    r=(int)(li[3])
    if(d[e]-d[s]>=0):
        tmp = d[e]-d[s]+1
    else:
        tmp = d[e]+8-d[s]
    total=0
    temps = tmp
    while tmp<=r:
        if(tmp>=l):
            total+=1
            day = tmp
        tmp=tmp+7
    if(total==0):
        day="impossible"
    elif(total!=1):
        day="many"

    print(day)
    t-=1

# %%
t = int(input())
for i in range(t):
    n = int(input())
    li = list(map(int, input().split()))
    sum1 = li[0]
    sum2 = 0
    if n >= 2:
        sum2 = li[1] 
    if n >= 3:
        sum2 = li[2]+li[1]
    for i in range(3, n, 2):
        sum1 += li[i]
        if i != n-1:
            
            sum2 += li[i+1]
    if sum1 < sum2:
        print("second")
    elif sum1 > sum2:
        print("first")
    else:
        print("draw")

# %%
# cook your dish here
t=int(input())
for i in range(t):
    n=int(input())
    a=list(map(int,input().split()))
    s1=0
    s2=0
    a.sort(reverse=True)
    for i in range(len(a)):
        if i==0:
            s2+=a[i]
        elif i==1:
            s1+=a[i]
        elif i%2==0:
            s1+=a[i]
        else:
            s2+=a[i]
    if s1==s2:
        print("draw")
    elif s1>s2:
        print("second")
    else:
        print("first")

# %%
possible_primes = (3, 5, 7, 11, 13, 17)
swapnodes = ((0, 1), (0, 3), (1, 2), (1, 4), (2, 5), (3, 4), (3, 6), (4, 5), (4, 7), (5, 8), (6, 7), (7, 8))
queue = [[1, 2, 3, 4, 5, 6, 7,8 ,9]]
possiblegrids = {(1, 2, 3,4, 5, 6, 7, 8, 9 ) : 0}
while queue:
    currg = queue.pop(0)
    for node in swapnodes:
        if currg[node[0]] + currg[node[1]] in possible_primes:
            newg = currg[:]
            newg[node[0]], newg[node[1]] = newg[node[1]], newg[node[0]]
        if tuple(newg) not in possiblegrids:
            possiblegrids[tuple(newg)] = possiblegrids[tuple(currg)] + 1
        queue.append(newg)
for i in range(int(input())):
    input()
    puzzle_matrix = []
    for i in range(3):
        puzzle_matrix += list(map(int, input().split()))
    puzzle_matrix = tuple(puzzle_matrix)
    if puzzle_matrix in possiblegrids:
        print(possiblegrids[puzzle_matrix])
    else:
        print(-1)
